# %%
import cv2
import numpy as np

from pysekiro.img_tools.get_vertices import roi

# ---*---

# 获取数值
def get_value(target_img):
    count = 0
    for pixel in target_img[0]:
        if pixel == 0:
            break
        count += 1
    return count

# ---*---

# 获取自身生命 (max 257)
def get_Self_HP(img):
    img_roi = roi(img, x=48, x_w=305, y=409, y_h=409+1)    # x, x_w, y, y_h 获取自 get_vertices.py
    b, g ,r =cv2.split(img_roi)    # 颜色通道分离
    retval, img_th = cv2.threshold(g, 50, 255, cv2.THRESH_TOZERO)              # 图像阈值处理，像素点的值低于50的设置为0
    retval, img_th = cv2.threshold(img_th, 70, 255, cv2.THRESH_TOZERO_INV)    # 图像阈值处理，像素点的值高于70的设置为0
    Self_HP = get_value(img_th)    # 获取数值
    return Self_HP

# ---*---

# up to data
# 获取自身架势 (max 82)
def get_Self_Posture(img):
    img_roi = roi(img, x=401, x_w=483, y=389, y_h=389+1)    # x, x_w, y, y_h 获取自 get_vertices.py
    b, g ,r =cv2.split(img_roi)    # 颜色通道分离
    white_line = r[0][0]
    if 155 < white_line < 170 or white_line > 250:
        canny = cv2.Canny(cv2.GaussianBlur(r,(3,3),0), 0, 100)
        Self_Posture =  np.argmax(canny)
    else:
        Self_Posture = 0
    return Self_Posture

# outdata
# 获取自身架势 (max 82)
def o_get_Self_Posture(img):
    img_roi = roi(img, x=401, x_w=483, y=389, y_h=389+1)    # x, x_w, y, y_h 获取自 get_vertices.py
    b, g ,r =cv2.split(img_roi)    # 颜色通道分离
    if r[0][0] > 250:
        retval, img_th = cv2.threshold(r, 200, 255, cv2.THRESH_TOZERO)    # 图像阈值处理，像素点的值低于200的设置为0
        Self_Posture = get_value(img_th)
    elif 155 < r[0][0] < 170:
        retval, img_th = cv2.threshold(r, 100, 255, cv2.THRESH_TOZERO)    # 图像阈值处理，像素点的值低于100的设置为0
        # retval, img_th = cv2.threshold(img_th, 170, 255, cv2.THRESH_TOZERO_INV)    # 图像阈值处理，像素点的值高于170的设置为0
        Self_Posture = get_value(img_th)
    else:
        img_th = None
        Self_Posture = 0
    # print('\n', 'Self_Posture', img_th)
#     print(Self_Posture)
    return Self_Posture

# ---*---

# 获取目标生命 (max 168)
def get_Target_HP(img):
    img_roi = roi(img, x=48, x_w=216, y=41, y_h=41+1)    # x, x_w, y, y_h 获取自 get_vertices.py
    b, g ,r =cv2.split(img_roi)    # 颜色通道分离
    retval, img_th = cv2.threshold(g, 25, 255, cv2.THRESH_TOZERO)             # 图像阈值处理，像素点的值低于40的设置为0
    retval, img_th = cv2.threshold(img_th, 70, 255, cv2.THRESH_TOZERO_INV)    # 图像阈值处理，像素点的值高于70的设置为0
    Target_HP = get_value(img_th)    # 获取数值
    # print('\n', 'Target_HP', img_th)
#     print(Target_HP)
    return Target_HP

# ---*---

# up to data
# 获取目标架势 (max 143)
def get_Target_Posture(img):
    img_roi = roi(img, x=401, x_w=544, y=29, y_h=29+1)    # x, x_w, y, y_h 获取自 get_vertices.py
    b, g ,r =cv2.split(img_roi)    # 颜色通道分离
    white_line = r[0][0]
    if white_line > 190:
        canny = cv2.Canny(cv2.GaussianBlur(r,(3,3),0), 0, 100)
        Target_Posture =  np.argmax(canny)
    else:
        Target_Posture = 0
    return Target_Posture

# outdata
# 获取目标架势 (max 143)
def o_get_Target_Posture(img):
    img_roi = roi(img, x=401, x_w=544, y=29, y_h=29+1)    # x, x_w, y, y_h 获取自 get_vertices.py
    b, g ,r =cv2.split(img_roi)    # 颜色通道分离
    if r[0][0] > 250:
        retval, img_th = cv2.threshold(r, 140, 255, cv2.THRESH_TOZERO)    # 图像阈值处理，像素点的值低于140的设置为0
        Target_Posture = get_value(img_th)
    elif r[0][0] > 190:
        retval, img_th = cv2.threshold(r, 120, 255, cv2.THRESH_TOZERO)    # 图像阈值处理，像素点的值低于120的设置为0
        Target_Posture = get_value(img_th)
    else:
        img_th = None
        Target_Posture = 0
    # print('\n', 'Target_Posture', img_th)
#     print(Target_Posture)
    return Target_Posture

# ---*---

def get_status(img):
    Self_HP, Self_Posture, Target_HP, Target_Posture = get_Self_HP(img), get_Self_Posture(img), get_Target_HP(img), get_Target_Posture(img)
    status_info = f'Self HP: {Self_HP:>3}, Self Posture: {Self_Posture:>3}, Target HP: {Target_HP:>3}, Target Posture: {Target_Posture:>3} . '
    return Self_HP, Self_Posture, Target_HP, Target_Posture, status_info

def o_get_status(img):
    o_Self_Posture, o_Target_Posture = o_get_Self_Posture(img), o_get_Target_Posture(img)
    return o_Self_Posture, o_Target_Posture

# %%
from pysekiro.img_tools.grab_screen import get_screen
from pysekiro.key_tools.get_keys import key_check

def main():

    paused = True
    print("Ready!")

    while True:
        keys = key_check()
        if paused:
            if 'T' in keys:
                paused = False
                print('Starting!')
        else:

            screen = get_screen()    # 获取屏幕图像

            # status_info = get_status(screen)[4]    # 显示状态信息
            # print('\r' + status_info, end='\n')

            Self_HP, Self_Posture, Target_HP, Target_Posture = get_status(screen)[:4]
            o_Self_Posture, o_Target_Posture = o_get_status(screen)
            print(f'\r读取结果：自身生命{Self_HP:>4} 【自身架势{Self_Posture:>4} 自身架势（旧）{o_Self_Posture:>4}】 目标生命{Target_HP:>4} 【目标架势{Target_Posture:>4} 目标架势（旧）{o_Target_Posture:>4}】')

            # 校准线
            screen[409:, [48, 49, 304, 305], :] = 255    # 自身生命

            # screen[389, 401:483, :] = 255    # 自身架势
            screen[[384, 385, 392,393], 401:483, :] = 255    # 自身架势
            screen[389:, 401, :] = 255    # 自身架势中线

            screen[:41, [48, 49, 215, 216], :] = 255    # 目标生命

            # screen[29, 401:544, :] = 255    # 目标架势
            screen[[25, 26, 32, 33], 401:544, :] = 255    # 目标架势
            screen[:29, 401, :] = 255    # 目标架势中线

            cv2.imshow('screen', screen)
            cv2.waitKey(200)

            if 'P' in keys:    # 结束
                cv2.destroyAllWindows()
                break

    print('\nDone!')

# %%
main()
# Out:
# Ready!
# Starting!
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势   9 自身架势（旧）  82】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势  11 自身架势（旧）  11】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势  11 自身架势（旧）  11】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势  11 自身架势（旧）  11】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势  11 自身架势（旧）  11】 目标生命 165 【目标架势  11 目标架势（旧）  11】
# 读取结果：自身生命 257 【自身架势  11 自身架势（旧）  11】 目标生命 165 【目标架势  11 目标架势（旧）  11】
# 读取结果：自身生命 257 【自身架势  11 自身架势（旧）  11】 目标生命 165 【目标架势  10 目标架势（旧）  10】
# 读取结果：自身生命 257 【自身架势  11 自身架势（旧）  11】 目标生命 165 【目标架势  13 目标架势（旧）  13】
# 读取结果：自身生命 257 【自身架势  11 自身架势（旧）  11】 目标生命 165 【目标架势  13 目标架势（旧）  13】
# 读取结果：自身生命 257 【自身架势  11 自身架势（旧）  11】 目标生命 165 【目标架势  14 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势  11 自身架势（旧）  11】 目标生命 165 【目标架势  13 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势   9 自身架势（旧）   9】 目标生命 165 【目标架势  13 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势   1 自身架势（旧）   1】 目标生命 165 【目标架势  13 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势   1 自身架势（旧）   1】 目标生命 165 【目标架势  13 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势   1 自身架势（旧）   1】 目标生命 165 【目标架势  13 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势  18 自身架势（旧）  21】 目标生命 165 【目标架势  18 目标架势（旧）  18】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 165 【目标架势  15 目标架势（旧）  16】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 165 【目标架势  15 目标架势（旧）  16】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 165 【目标架势  16 目标架势（旧）  16】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 165 【目标架势   1 目标架势（旧）  28】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 165 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 165 【目标架势  28 目标架势（旧）  28】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 165 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 165 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 165 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 165 【目标架势  28 目标架势（旧）  28】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 165 【目标架势   1 目标架势（旧）  26】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 161 【目标架势   1 目标架势（旧）  27】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 161 【目标架势   1 目标架势（旧）  27】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 161 【目标架势   1 目标架势（旧）  27】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 161 【目标架势   1 目标架势（旧）  29】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 161 【目标架势   1 目标架势（旧）  28】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 161 【目标架势   1 目标架势（旧）  26】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 161 【目标架势  27 目标架势（旧）  27】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 161 【目标架势  27 目标架势（旧）  27】
# 读取结果：自身生命 257 【自身架势  16 自身架势（旧）  17】 目标生命 161 【目标架势  26 目标架势（旧）  27】
# 读取结果：自身生命 257 【自身架势  16 自身架势（旧）  17】 目标生命 161 【目标架势  26 目标架势（旧）  27】
# 读取结果：自身生命 257 【自身架势  23 自身架势（旧）  23】 目标生命 161 【目标架势  31 目标架势（旧）  31】
# 读取结果：自身生命 257 【自身架势  23 自身架势（旧）  24】 目标生命 161 【目标架势   1 目标架势（旧）  31】
# 读取结果：自身生命 257 【自身架势  27 自身架势（旧）  31】 目标生命 161 【目标架势   1 目标架势（旧）  35】
# 读取结果：自身生命 257 【自身架势  30 自身架势（旧）  30】 目标生命 161 【目标架势  35 目标架势（旧）  35】
# 读取结果：自身生命 257 【自身架势  30 自身架势（旧）  30】 目标生命 161 【目标架势  35 目标架势（旧）  35】
# 读取结果：自身生命 257 【自身架势  27 自身架势（旧）  30】 目标生命 156 【目标架势   1 目标架势（旧）  39】
# 读取结果：自身生命 257 【自身架势  30 自身架势（旧）  30】 目标生命 156 【目标架势  39 目标架势（旧）  39】
# 读取结果：自身生命 257 【自身架势  29 自身架势（旧）  29】 目标生命 156 【目标架势  39 目标架势（旧）  39】
# 读取结果：自身生命 257 【自身架势  30 自身架势（旧）  34】 目标生命 156 【目标架势  41 目标架势（旧）  41】
# 读取结果：自身生命 257 【自身架势  35 自身架势（旧）  82】 目标生命 156 【目标架势  43 目标架势（旧）  43】
# 读取结果：自身生命 257 【自身架势  38 自身架势（旧）  38】 目标生命 156 【目标架势   1 目标架势（旧）  43】
# 读取结果：自身生命 257 【自身架势  40 自身架势（旧）  82】 目标生命 156 【目标架势   1 目标架势（旧）  45】
# 读取结果：自身生命 257 【自身架势  42 自身架势（旧）  43】 目标生命 156 【目标架势  45 目标架势（旧）  45】
# 读取结果：自身生命 257 【自身架势  44 自身架势（旧）  54】 目标生命 156 【目标架势   1 目标架势（旧）  47】
# 读取结果：自身生命 246 【自身架势  56 自身架势（旧）  57】 目标生命 156 【目标架势  47 目标架势（旧）  47】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  81】 目标生命 156 【目标架势  49 目标架势（旧）  49】
# 读取结果：自身生命 246 【自身架势  61 自身架势（旧）  62】 目标生命 156 【目标架势   1 目标架势（旧）  49】
# 读取结果：自身生命 246 【自身架势  60 自身架势（旧）  60】 目标生命 156 【目标架势  49 目标架势（旧）  49】
# 读取结果：自身生命 246 【自身架势  56 自身架势（旧）  57】 目标生命 156 【目标架势   1 目标架势（旧）  49】
# 读取结果：自身生命 246 【自身架势  79 自身架势（旧）  78】 目标生命 156 【目标架势   1 目标架势（旧）  53】
# 读取结果：自身生命 246 【自身架势  66 自身架势（旧）  66】 目标生命 156 【目标架势  53 目标架势（旧）  53】
# 读取结果：自身生命 246 【自身架势  66 自身架势（旧）  60】 目标生命 156 【目标架势  53 目标架势（旧）  53】
# 读取结果：自身生命 246 【自身架势  66 自身架势（旧）  60】 目标生命 156 【目标架势  53 目标架势（旧）  53】
# 读取结果：自身生命 246 【自身架势  66 自身架势（旧）  60】 目标生命 156 【目标架势  53 目标架势（旧）  53】
# 读取结果：自身生命 246 【自身架势  66 自身架势（旧）  60】 目标生命 156 【目标架势  53 目标架势（旧）  53】
# 读取结果：自身生命 246 【自身架势  66 自身架势（旧）  60】 目标生命 156 【目标架势  52 目标架势（旧）  52】
# 读取结果：自身生命 246 【自身架势  66 自身架势（旧）  60】 目标生命 156 【目标架势   1 目标架势（旧）  51】
# 读取结果：自身生命 246 【自身架势  66 自身架势（旧）  60】 目标生命 152 【目标架势   1 目标架势（旧）  54】
# 读取结果：自身生命 246 【自身架势  66 自身架势（旧）  60】 目标生命 152 【目标架势   1 目标架势（旧）  54】
# 读取结果：自身生命 246 【自身架势  66 自身架势（旧）  60】 目标生命 152 【目标架势   1 目标架势（旧）  53】
# 读取结果：自身生命 246 【自身架势  66 自身架势（旧）  60】 目标生命 152 【目标架势   1 目标架势（旧）  56】
# 读取结果：自身生命 246 【自身架势  66 自身架势（旧）  60】 目标生命 152 【目标架势  53 目标架势（旧）  54】
# 读取结果：自身生命 246 【自身架势  62 自身架势（旧）  60】 目标生命 152 【目标架势  54 目标架势（旧）  54】
# 读取结果：自身生命 246 【自身架势  66 自身架势（旧）  60】 目标生命 152 【目标架势  53 目标架势（旧）  54】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 152 【目标架势  53 目标架势（旧）  54】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  62】 目标生命 152 【目标架势  58 目标架势（旧）  58】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  62】 目标生命 152 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  68 自身架势（旧）  62】 目标生命 152 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  68 自身架势（旧）  62】 目标生命 152 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  68 自身架势（旧）  62】 目标生命 152 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  68 自身架势（旧）  62】 目标生命 152 【目标架势  60 目标架势（旧）  61】
# 读取结果：自身生命 246 【自身架势  68 自身架势（旧）  62】 目标生命 152 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  68 自身架势（旧）  61】 目标生命 152 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  70 自身架势（旧）  64】 目标生命 152 【目标架势  63 目标架势（旧）  66】
# 读取结果：自身生命 246 【自身架势  73 自身架势（旧）  64】 目标生命 152 【目标架势  66 目标架势（旧）  66】
# 读取结果：自身生命 246 【自身架势  73 自身架势（旧）  64】 目标生命 152 【目标架势  63 目标架势（旧）  66】
# 读取结果：自身生命 246 【自身架势  73 自身架势（旧）  64】 目标生命 152 【目标架势  67 目标架势（旧）  70】
# 读取结果：自身生命 246 【自身架势  73 自身架势（旧）  64】 目标生命 152 【目标架势  66 目标架势（旧）  70】
# 读取结果：自身生命 246 【自身架势  73 自身架势（旧）  64】 目标生命 152 【目标架势  66 目标架势（旧）  69】
# 读取结果：自身生命 246 【自身架势  73 自身架势（旧）  64】 目标生命 152 【目标架势  67 目标架势（旧）  70】
# 读取结果：自身生命 246 【自身架势  73 自身架势（旧）  64】 目标生命 152 【目标架势  69 目标架势（旧）  69】
# 读取结果：自身生命 246 【自身架势  71 自身架势（旧）  64】 目标生命 152 【目标架势  68 目标架势（旧）  68】
# 读取结果：自身生命 246 【自身架势  71 自身架势（旧）  64】 目标生命 152 【目标架势  67 目标架势（旧）  67】
# 读取结果：自身生命 246 【自身架势  71 自身架势（旧）  64】 目标生命 152 【目标架势  66 目标架势（旧）  66】
# 读取结果：自身生命 246 【自身架势  71 自身架势（旧）  64】 目标生命 152 【目标架势  66 目标架势（旧）  66】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  62】 目标生命 152 【目标架势  66 目标架势（旧）  66】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  62】 目标生命 152 【目标架势  66 目标架势（旧）  66】
# 读取结果：自身生命 246 【自身架势  76 自身架势（旧）  66】 目标生命 152 【目标架势  66 目标架势（旧）  66】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 152 【目标架势  66 目标架势（旧）  66】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 152 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 152 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 152 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 152 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 152 【目标架势  66 目标架势（旧）  66】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 147 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 147 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 147 【目标架势  68 目标架势（旧）  68】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 147 【目标架势  71 目标架势（旧）  71】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  67】 目标生命 147 【目标架势  71 目标架势（旧）  71】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 143 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 143 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 143 【目标架势  73 目标架势（旧）  74】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 143 【目标架势  76 目标架势（旧）  77】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 143 【目标架势  76 目标架势（旧）  76】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 138 【目标架势  79 目标架势（旧）  80】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 138 【目标架势  79 目标架势（旧）  80】
# 读取结果：自身生命 246 【自身架势  78 自身架势（旧）  67】 目标生命 138 【目标架势  79 目标架势（旧）  80】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 138 【目标架势   1 目标架势（旧）  84】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 138 【目标架势  83 目标架势（旧）  84】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 138 【目标架势  83 目标架势（旧）  84】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 138 【目标架势  83 目标架势（旧）  84】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 138 【目标架势  83 目标架势（旧）  84】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 138 【目标架势  83 目标架势（旧）  84】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 138 【目标架势  83 目标架势（旧）  84】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 138 【目标架势  81 目标架势（旧）  81】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 138 【目标架势  81 目标架势（旧）  81】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 138 【目标架势  81 目标架势（旧）  81】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 138 【目标架势  84 目标架势（旧）  84】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 138 【目标架势  81 目标架势（旧）  84】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 138 【目标架势  81 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 138 【目标架势   1 目标架势（旧）  85】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 138 【目标架势  81 目标架势（旧）  85】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  81】 目标生命 138 【目标架势  81 目标架势（旧）  86】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  81】 目标生命 138 【目标架势  84 目标架势（旧）  84】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  67】 目标生命 138 【目标架势  84 目标架势（旧）  84】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  67】 目标生命 138 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 138 【目标架势  85 目标架势（旧）  89】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 138 【目标架势  83 目标架势（旧）  87】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 138 【目标架势  83 目标架势（旧）  87】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 138 【目标架势  83 目标架势（旧）  87】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 138 【目标架势  95 目标架势（旧）  99】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 138 【目标架势  95 目标架势（旧）  99】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 138 【目标架势  95 目标架势（旧）  99】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 138 【目标架势  95 目标架势（旧）  99】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 138 【目标架势  95 目标架势（旧）  99】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 138 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 138 【目标架势  95 目标架势（旧）  99】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 138 【目标架势   1 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 138 【目标架势   1 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 134 【目标架势   1 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 134 【目标架势   1 目标架势（旧）  98】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 134 【目标架势  93 目标架势（旧）  97】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 134 【目标架势  96 目标架势（旧） 100】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 134 【目标架势  96 目标架势（旧） 100】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 134 【目标架势  97 目标架势（旧） 101】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 134 【目标架势  97 目标架势（旧） 101】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 134 【目标架势  97 目标架势（旧） 101】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  81】 目标生命 134 【目标架势  96 目标架势（旧） 100】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  70】 目标生命 134 【目标架势  96 目标架势（旧） 100】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 134 【目标架势  98 目标架势（旧） 103】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  67】 目标生命 134 【目标架势  98 目标架势（旧） 102】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 134 【目标架势  98 目标架势（旧） 102】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  67】 目标生命 134 【目标架势 103 目标架势（旧） 104】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  67】 目标生命 134 【目标架势  99 目标架势（旧） 104】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 134 【目标架势  99 目标架势（旧） 104】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 134 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 134 【目标架势 107 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 134 【目标架势 107 目标架势（旧） 128】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 134 【目标架势 107 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 134 【目标架势 107 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 130 【目标架势 110 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 130 【目标架势 110 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 130 【目标架势 110 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 130 【目标架势 113 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 130 【目标架势 113 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 130 【目标架势 113 目标架势（旧） 141】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 125 【目标架势 116 目标架势（旧） 121】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 125 【目标架势 116 目标架势（旧） 121】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  76】 目标生命 125 【目标架势 116 目标架势（旧） 136】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 125 【目标架势 120 目标架势（旧） 138】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 125 【目标架势 119 目标架势（旧） 124】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 125 【目标架势 119 目标架势（旧） 129】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 125 【目标架势 119 目标架势（旧） 138】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 125 【目标架势 119 目标架势（旧） 128】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 125 【目标架势 131 目标架势（旧） 136】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 125 【目标架势 131 目标架势（旧） 136】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 125 【目标架势 131 目标架势（旧） 136】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 125 【目标架势 131 目标架势（旧） 136】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 125 【目标架势 131 目标架势（旧） 136】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 125 【目标架势 131 目标架势（旧） 141】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 125 【目标架势 131 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 125 【目标架势 130 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 121 【目标架势 132 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 121 【目标架势 132 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 121 【目标架势 132 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 116 【目标架势 135 目标架势（旧） 141】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 116 【目标架势 135 目标架势（旧） 141】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 116 【目标架势 135 目标架势（旧） 140】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 116 【目标架势 138 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 116 【目标架势 138 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 116 【目标架势 139 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 116 【目标架势 139 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 116 【目标架势 138 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势  79 自身架势（旧）  79】 目标生命 116 【目标架势 138 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 116 【目标架势 141 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 116 【目标架势 141 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 112 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 112 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 112 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 112 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 112 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 112 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 112 【目标架势   0 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 112 【目标架势   0 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 112 【目标架势   0 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 112 【目标架势   0 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 112 【目标架势   0 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 112 【目标架势   0 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 112 【目标架势   0 目标架势（旧） 142】
# 读取结果：自身生命 246 【自身架势  74 自身架势（旧）  65】 目标生命 112 【目标架势   0 目标架势（旧） 142】
# 读取结果：自身生命 257 【自身架势   1 自身架势（旧）   1】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 257 【自身架势   1 自身架势（旧）   1】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 257 【自身架势   1 自身架势（旧）   1】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   1 目标架势（旧）   1】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   1 目标架势（旧）   1】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  10 目标架势（旧）  10】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   9 目标架势（旧）  10】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  11 目标架势（旧）  11】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  10 目标架势（旧）  10】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  10 目标架势（旧）  10】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  10 目标架势（旧）  10】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  10 目标架势（旧）  10】
# 读取结果：自身生命 257 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  10 目标架势（旧）  10】
# 读取结果：自身生命 257 【自身架势  18 自身架势（旧）  25】 目标生命 168 【目标架势  14 目标架势（旧）  15】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 168 【目标架势  12 目标架势（旧）  13】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 168 【目标架势  12 目标架势（旧）  12】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 168 【目标架势  12 目标架势（旧）  12】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 168 【目标架势  12 目标架势（旧）  12】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 168 【目标架势  12 目标架势（旧）  12】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 168 【目标架势  12 目标架势（旧）  12】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 168 【目标架势  13 目标架势（旧）  13】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 168 【目标架势  13 目标架势（旧）  13】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 167 【目标架势  14 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 167 【目标架势   1 目标架势（旧）  13】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 167 【目标架势  14 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 167 【目标架势  14 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 167 【目标架势  14 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势  18 自身架势（旧）  21】 目标生命 167 【目标架势  15 目标架势（旧）  15】
# 读取结果：自身生命 257 【自身架势  20 自身架势（旧）  21】 目标生命 167 【目标架势  14 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势  18 自身架势（旧）  18】 目标生命 167 【目标架势  13 目标架势（旧）  13】
# 读取结果：自身生命 257 【自身架势  18 自身架势（旧）  18】 目标生命 167 【目标架势  12 目标架势（旧）  12】
# 读取结果：自身生命 257 【自身架势  18 自身架势（旧）  18】 目标生命 167 【目标架势  11 目标架势（旧）  11】
# 读取结果：自身生命 257 【自身架势  18 自身架势（旧）  18】 目标生命 167 【目标架势  13 目标架势（旧）  13】
# 读取结果：自身生命 257 【自身架势  18 自身架势（旧）  18】 目标生命 167 【目标架势  12 目标架势（旧）  13】
# 读取结果：自身生命 257 【自身架势  18 自身架势（旧）  18】 目标生命 167 【目标架势   1 目标架势（旧）  13】
# 读取结果：自身生命 257 【自身架势  18 自身架势（旧）  19】 目标生命 167 【目标架势  14 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势  18 自身架势（旧）  18】 目标生命 167 【目标架势  14 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势  14 自身架势（旧）  15】 目标生命 167 【目标架势  14 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势  14 自身架势（旧）  15】 目标生命 167 【目标架势  13 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势  14 自身架势（旧）  15】 目标生命 167 【目标架势  13 目标架势（旧）  14】
# 读取结果：自身生命 257 【自身架势  21 自身架势（旧）  22】 目标生命 167 【目标架势   1 目标架势（旧）  18】
# 读取结果：自身生命 257 【自身架势  26 自身架势（旧）  29】 目标生命 167 【目标架势  22 目标架势（旧）  22】
# 读取结果：自身生命 257 【自身架势  28 自身架势（旧）  29】 目标生命 167 【目标架势  22 目标架势（旧）  22】
# 读取结果：自身生命 257 【自身架势  28 自身架势（旧）  29】 目标生命 167 【目标架势  22 目标架势（旧）  22】
# 读取结果：自身生命 257 【自身架势  28 自身架势（旧）  29】 目标生命 163 【目标架势  26 目标架势（旧）  26】
# 读取结果：自身生命 257 【自身架势  28 自身架势（旧）  29】 目标生命 163 【目标架势  26 目标架势（旧）  26】
# 读取结果：自身生命 257 【自身架势  27 自身架势（旧）  28】 目标生命 163 【目标架势  26 目标架势（旧）  26】
# 读取结果：自身生命 257 【自身架势  29 自身架势（旧）  46】 目标生命 163 【目标架势  28 目标架势（旧）  28】
# 读取结果：自身生命 257 【自身架势  34 自身架势（旧）  38】 目标生命 163 【目标架势  30 目标架势（旧）  30】
# 读取结果：自身生命 257 【自身架势  37 自身架势（旧）  37】 目标生命 163 【目标架势  30 目标架势（旧）  30】
# 读取结果：自身生命 257 【自身架势  37 自身架势（旧）  37】 目标生命 163 【目标架势  30 目标架势（旧）  30】
# 读取结果：自身生命 257 【自身架势  38 自身架势（旧）  42】 目标生命 163 【目标架势  32 目标架势（旧）  32】
# 读取结果：自身生命 257 【自身架势  43 自身架势（旧）  82】 目标生命 163 【目标架势  34 目标架势（旧）  35】
# 读取结果：自身生命 257 【自身架势  48 自身架势（旧）  82】 目标生命 163 【目标架势  36 目标架势（旧）  36】
# 读取结果：自身生命 257 【自身架势  47 自身架势（旧）  51】 目标生命 163 【目标架势  36 目标架势（旧）  36】
# 读取结果：自身生命 246 【自身架势  60 自身架势（旧）  60】 目标生命 163 【目标架势  36 目标架势（旧）  36】
# 读取结果：自身生命 246 【自身架势  60 自身架势（旧）  60】 目标生命 163 【目标架势  36 目标架势（旧）  36】
# 读取结果：自身生命 246 【自身架势  60 自身架势（旧）  60】 目标生命 163 【目标架势  36 目标架势（旧）  36】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  81】 目标生命 163 【目标架势  40 目标架势（旧）  40】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  70】 目标生命 163 【目标架势  40 目标架势（旧）  40】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  62】 目标生命 163 【目标架势   1 目标架势（旧）  41】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  62】 目标生命 163 【目标架势  40 目标架势（旧）  40】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  62】 目标生命 163 【目标架势   1 目标架势（旧）  41】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  62】 目标生命 163 【目标架势   1 目标架势（旧）  41】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  62】 目标生命 163 【目标架势   1 目标架势（旧）  41】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  62】 目标生命 163 【目标架势   1 目标架势（旧）  38】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  62】 目标生命 163 【目标架势   1 目标架势（旧）  41】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  62】 目标生命 163 【目标架势   1 目标架势（旧）  40】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  62】 目标生命 163 【目标架势   1 目标架势（旧）  41】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  62】 目标生命 163 【目标架势  41 目标架势（旧）  41】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  61】 目标生命 163 【目标架势  41 目标架势（旧）  41】
# 读取结果：自身生命 246 【自身架势  71 自身架势（旧）  63】 目标生命 163 【目标架势  45 目标架势（旧）  45】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  63】 目标生命 163 【目标架势   1 目标架势（旧）  45】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  63】 目标生命 163 【目标架势   1 目标架势（旧）  45】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  63】 目标生命 163 【目标架势   1 目标架势（旧）  49】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  63】 目标生命 163 【目标架势   1 目标架势（旧）  49】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  63】 目标生命 163 【目标架势   1 目标架势（旧）  48】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  63】 目标生命 163 【目标架势   1 目标架势（旧）  49】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  63】 目标生命 163 【目标架势   1 目标架势（旧）  49】
# 读取结果：自身生命 246 【自身架势  70 自身架势（旧）  63】 目标生命 163 【目标架势   1 目标架势（旧）  47】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 163 【目标架势   1 目标架势（旧）  46】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 163 【目标架势   1 目标架势（旧）  46】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 163 【目标架势   1 目标架势（旧）  46】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 158 【目标架势   1 目标架势（旧）  49】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 158 【目标架势   1 目标架势（旧）  49】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 158 【目标架势   1 目标架势（旧）  51】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 158 【目标架势   1 目标架势（旧）  51】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 158 【目标架势   1 目标架势（旧）  51】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 154 【目标架势   1 目标架势（旧）  54】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 154 【目标架势   1 目标架势（旧）  54】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 154 【目标架势   1 目标架势（旧）  54】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 154 【目标架势   1 目标架势（旧）  57】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 154 【目标架势   1 目标架势（旧）  56】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 154 【目标架势   1 目标架势（旧）  53】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  66】 目标生命 154 【目标架势   1 目标架势（旧）  55】
# 读取结果：自身生命 246 【自身架势  65 自身架势（旧）  65】 目标生命 154 【目标架势   1 目标架势（旧）  54】
# 读取结果：自身生命 246 【自身架势  62 自身架势（旧）  62】 目标生命 154 【目标架势   1 目标架势（旧）  54】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  61】 目标生命 154 【目标架势   1 目标架势（旧）  58】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  61】 目标生命 154 【目标架势  58 目标架势（旧）  58】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  61】 目标生命 154 【目标架势   1 目标架势（旧）  62】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  61】 目标生命 154 【目标架势   1 目标架势（旧）  62】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  61】 目标生命 154 【目标架势   1 目标架势（旧）  61】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  61】 目标生命 150 【目标架势  64 目标架势（旧）  65】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  61】 目标生命 150 【目标架势  64 目标架势（旧）  65】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  61】 目标生命 150 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  67】 目标生命 150 【目标架势  68 目标架势（旧）  69】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 150 【目标架势  67 目标架势（旧）  68】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 150 【目标架势  66 目标架势（旧）  67】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 150 【目标架势  66 目标架势（旧）  66】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 150 【目标架势   1 目标架势（旧）  66】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 150 【目标架势   1 目标架势（旧）  66】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 150 【目标架势  66 目标架势（旧）  66】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 148 【目标架势  67 目标架势（旧）  68】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 148 【目标架势   1 目标架势（旧）  68】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 147 【目标架势   1 目标架势（旧）  69】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 147 【目标架势   1 目标架势（旧）  68】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 143 【目标架势   1 目标架势（旧）  68】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 143 【目标架势   1 目标架势（旧）  65】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 143 【目标架势  62 目标架势（旧）  62】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 143 【目标架势  64 目标架势（旧）  65】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 143 【目标架势  64 目标架势（旧）  64】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 143 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  67】 目标生命 143 【目标架势  65 目标架势（旧）  65】
# 读取结果：自身生命 246 【自身架势  79 自身架势（旧）  66】 目标生命 143 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 143 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  71 自身架势（旧）  64】 目标生命 143 【目标架势  62 目标架势（旧）  62】
# 读取结果：自身生命 246 【自身架势  71 自身架势（旧）  64】 目标生命 143 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  71 自身架势（旧）  64】 目标生命 138 【目标架势  64 目标架势（旧）  65】
# 读取结果：自身生命 246 【自身架势  71 自身架势（旧）  64】 目标生命 138 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  71 自身架势（旧）  64】 目标生命 138 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  71 自身架势（旧）  64】 目标生命 138 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  71 自身架势（旧）  64】 目标生命 138 【目标架势  67 目标架势（旧）  67】
# 读取结果：自身生命 246 【自身架势  71 自身架势（旧）  64】 目标生命 138 【目标架势  66 目标架势（旧）  67】
# 读取结果：自身生命 246 【自身架势  71 自身架势（旧）  64】 目标生命 138 【目标架势  67 目标架势（旧）  68】
# 读取结果：自身生命 246 【自身架势  71 自身架势（旧）  64】 目标生命 138 【目标架势  67 目标架势（旧）  67】
# 读取结果：自身生命 246 【自身架势  69 自身架势（旧）  62】 目标生命 138 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 138 【目标架势  71 目标架势（旧）  68】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 138 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 138 【目标架势  71 目标架势（旧）  68】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 138 【目标架势  75 目标架势（旧）  75】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 138 【目标架势  75 目标架势（旧）  71】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 138 【目标架势  75 目标架势（旧）  71】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 134 【目标架势   1 目标架势（旧）  79】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 134 【目标架势   1 目标架势（旧）  79】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 134 【目标架势  81 目标架势（旧）  81】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 134 【目标架势  81 目标架势（旧）  81】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 134 【目标架势  81 目标架势（旧）  81】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 130 【目标架势  84 目标架势（旧）  85】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 130 【目标架势  84 目标架势（旧）  85】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 130 【目标架势  84 目标架势（旧）  84】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 130 【目标架势  87 目标架势（旧）  87】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 130 【目标架势  84 目标架势（旧）  87】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 125 【目标架势  90 目标架势（旧）  91】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 125 【目标架势  90 目标架势（旧）  91】
# 读取结果：自身生命 246 【自身架势  75 自身架势（旧）  65】 目标生命 125 【目标架势  90 目标架势（旧）  91】
# 读取结果：自身生命 246 【自身架势  73 自身架势（旧）  64】 目标生命 125 【目标架势  90 目标架势（旧）  91】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 125 【目标架势  91 目标架势（旧）  95】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 125 【目标架势  90 目标架势（旧）  94】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 125 【目标架势  90 目标架势（旧）  94】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 125 【目标架势  90 目标架势（旧）  94】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 125 【目标架势  90 目标架势（旧）  94】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 125 【目标架势  90 目标架势（旧）  94】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 125 【目标架势  90 目标架势（旧）  94】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 125 【目标架势  93 目标架势（旧）  93】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 124 【目标架势  94 目标架势（旧）  94】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 123 【目标架势  95 目标架势（旧）  96】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 122 【目标架势  92 目标架势（旧）  95】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 122 【目标架势  93 目标架势（旧）  94】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 122 【目标架势  93 目标架势（旧）  93】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 122 【目标架势  93 目标架势（旧）  97】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 122 【目标架势  93 目标架势（旧）  97】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 122 【目标架势  94 目标架势（旧）  98】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 122 【目标架势  94 目标架势（旧）  98】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  94 目标架势（旧）  98】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  81】 目标生命 122 【目标架势  94 目标架势（旧）  98】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  73】 目标生命 122 【目标架势  94 目标架势（旧）  98】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  67】 目标生命 122 【目标架势  98 目标架势（旧） 102】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 122 【目标架势 101 目标架势（旧） 102】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 122 【目标架势 105 目标架势（旧） 136】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 122 【目标架势 105 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 122 【目标架势 105 目标架势（旧） 143】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 117 【目标架势 109 目标架势（旧） 110】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 117 【目标架势 109 目标架势（旧） 110】
# 读取结果：自身生命 246 【自身架势  80 自身架势（旧）  81】 目标生命 117 【目标架势 109 目标架势（旧） 110】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 117 【目标架势 111 目标架势（旧） 112】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 117 【目标架势 113 目标架势（旧） 114】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 117 【目标架势 110 目标架势（旧） 115】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 117 【目标架势 115 目标架势（旧） 116】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  81】 目标生命 117 【目标架势 115 目标架势（旧） 116】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  80】 目标生命 117 【目标架势 114 目标架势（旧） 118】
# 读取结果：自身生命 246 【自身架势   0 自身架势（旧）  82】 目标生命 117 【目标架势 116 目标架势（旧） 120】
# 读取结果：自身生命 235 【自身架势   0 自身架势（旧）  80】 目标生命 117 【目标架势 116 目标架势（旧） 120】
# 读取结果：自身生命 235 【自身架势   1 自身架势（旧）   1】 目标生命 117 【目标架势 116 目标架势（旧） 121】
# 读取结果：自身生命 235 【自身架势   1 自身架势（旧）   1】 目标生命 117 【目标架势 116 目标架势（旧） 120】
# 读取结果：自身生命 235 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 116 目标架势（旧） 121】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 116 目标架势（旧） 124】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 118 目标架势（旧） 119】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 117 目标架势（旧） 118】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 112 目标架势（旧） 116】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 110 目标架势（旧） 137】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 113 目标架势（旧） 114】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 111 目标架势（旧） 112】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 110 目标架势（旧） 111】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 110 目标架势（旧） 111】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 113 目标架势（旧） 114】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 113 目标架势（旧） 114】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 114 目标架势（旧） 115】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 114 目标架势（旧） 115】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 114 目标架势（旧） 115】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 114 目标架势（旧） 115】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 114 目标架势（旧） 115】
# 读取结果：自身生命  65 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势 114 目标架势（旧） 115】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 117 【目标架势 118 目标架势（旧） 119】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 117 【目标架势 117 目标架势（旧） 118】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 117 【目标架势 117 目标架势（旧） 118】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 117 【目标架势 117 目标架势（旧） 118】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 117 【目标架势 117 目标架势（旧） 118】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 117 【目标架势 117 目标架势（旧） 118】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 117 【目标架势 117 目标架势（旧） 118】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 116 【目标架势 118 目标架势（旧） 119】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 115 【目标架势 116 目标架势（旧） 121】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 115 【目标架势 116 目标架势（旧） 143】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 115 【目标架势 115 目标架势（旧） 143】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 111 【目标架势 116 目标架势（旧） 132】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 111 【目标架势 120 目标架势（旧） 120】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 111 【目标架势 119 目标架势（旧） 120】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 111 【目标架势 123 目标架势（旧） 123】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 111 【目标架势 122 目标架势（旧） 123】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 111 【目标架势 124 目标架势（旧） 124】
# 读取结果：自身生命  65 【自身架势  20 自身架势（旧）  21】 目标生命 111 【目标架势 124 目标架势（旧） 124】
# 读取结果：自身生命  65 【自身架势  19 自身架势（旧）  20】 目标生命 111 【目标架势 124 目标架势（旧） 124】
# 读取结果：自身生命  65 【自身架势  17 自身架势（旧）  18】 目标生命 111 【目标架势 124 目标架势（旧） 124】
# 读取结果：自身生命  65 【自身架势  15 自身架势（旧）  15】 目标生命 111 【目标架势 124 目标架势（旧） 124】
# 读取结果：自身生命  65 【自身架势  21 自身架势（旧）  21】 目标生命 111 【目标架势 128 目标架势（旧） 128】
# 读取结果：自身生命  65 【自身架势  21 自身架势（旧）  21】 目标生命 111 【目标架势 128 目标架势（旧） 128】
# 读取结果：自身生命  65 【自身架势  28 自身架势（旧）  28】 目标生命 111 【目标架势 132 目标架势（旧） 132】
# 读取结果：自身生命  65 【自身架势  28 自身架势（旧）  28】 目标生命 111 【目标架势 132 目标架势（旧） 132】
# 读取结果：自身生命  65 【自身架势  28 自身架势（旧）  28】 目标生命 107 【目标架势 136 目标架势（旧） 136】
# 读取结果：自身生命  65 【自身架势  28 自身架势（旧）  28】 目标生命 107 【目标架势 136 目标架势（旧） 136】
# 读取结果：自身生命  65 【自身架势  28 自身架势（旧）  28】 目标生命 107 【目标架势 136 目标架势（旧） 136】
# 读取结果：自身生命  65 【自身架势  27 自身架势（旧）  27】 目标生命 107 【目标架势 136 目标架势（旧） 136】
# 读取结果：自身生命  65 【自身架势  31 自身架势（旧）  32】 目标生命 107 【目标架势 138 目标架势（旧） 138】
# 读取结果：自身生命  65 【自身架势  36 自身架势（旧）  37】 目标生命 107 【目标架势 140 目标架势（旧） 140】
# 读取结果：自身生命  65 【自身架势  36 自身架势（旧）  37】 目标生命 107 【目标架势 140 目标架势（旧） 140】
# 读取结果：自身生命  65 【自身架势  40 自身架势（旧）  41】 目标生命 107 【目标架势 141 目标架势（旧） 142】
# 读取结果：自身生命  65 【自身架势  40 自身架势（旧）  41】 目标生命 107 【目标架势 141 目标架势（旧） 142】
# 读取结果：自身生命  65 【自身架势  45 自身架势（旧）  46】 目标生命 107 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  53 【自身架势  52 自身架势（旧）  82】 目标生命 107 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  42 【自身架势  79 自身架势（旧）  79】 目标生命 107 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  42 【自身架势  64 自身架势（旧）  65】 目标生命 107 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  42 【自身架势  64 自身架势（旧）  64】 目标生命 107 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  42 【自身架势  64 自身架势（旧）  64】 目标生命 107 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  42 【自身架势  73 自身架势（旧）  73】 目标生命 107 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  42 【自身架势  73 自身架势（旧）  73】 目标生命 107 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  42 【自身架势  73 自身架势（旧）  73】 目标生命 107 【目标架势   0 目标架势（旧） 142】
# 读取结果：自身生命  42 【自身架势  73 自身架势（旧）  73】 目标生命 107 【目标架势   0 目标架势（旧） 142】
# 读取结果：自身生命  42 【自身架势  73 自身架势（旧）  73】 目标生命 107 【目标架势   0 目标架势（旧） 142】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）  82】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）  82】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  16 目标架势（旧）  16】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  15 目标架势（旧）  16】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  16 目标架势（旧）  16】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  16 目标架势（旧）  16】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  16 目标架势（旧）  16】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  15 目标架势（旧）  16】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  15 目标架势（旧）  15】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  14 目标架势（旧）  14】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势  12 目标架势（旧）  13】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 167 【目标架势  15 目标架势（旧）  15】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 167 【目标架势  15 目标架势（旧）  15】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 164 【目标架势  17 目标架势（旧）  17】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 164 【目标架势  17 目标架势（旧）  17】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 164 【目标架势   1 目标架势（旧）  17】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 161 【目标架势  19 目标架势（旧）  20】
# 读取结果：自身生命  94 【自身架势   0 自身架势（旧）   0】 目标生命 161 【目标架势   1 目标架势（旧）  20】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 161 【目标架势  20 目标架势（旧）  20】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 161 【目标架势  20 目标架势（旧）  20】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 161 【目标架势  19 目标架势（旧）  20】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 161 【目标架势  19 目标架势（旧）  20】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 131 【目标架势   1 目标架势（旧）  29】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 131 【目标架势   1 目标架势（旧）  29】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 131 【目标架势  28 目标架势（旧）  29】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 131 【目标架势  28 目标架势（旧）  29】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 131 【目标架势  28 目标架势（旧）  29】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 128 【目标架势  31 目标架势（旧）  31】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 128 【目标架势  31 目标架势（旧）  31】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 128 【目标架势  31 目标架势（旧）  31】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 125 【目标架势  33 目标架势（旧）  34】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 125 【目标架势  33 目标架势（旧）  34】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 125 【目标架势  33 目标架势（旧）  34】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  36 目标架势（旧）  36】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  36 目标架势（旧）  36】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  38 目标架势（旧）  38】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  38 目标架势（旧）  38】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  38 目标架势（旧）  38】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  39 目标架势（旧）  39】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  39 目标架势（旧）  39】
# 读取结果：自身生命  75 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  39 目标架势（旧）  39】
# 读取结果：自身生命   0 【自身架势  20 自身架势（旧）  82】 目标生命 122 【目标架势  39 目标架势（旧）  39】
# 读取结果：自身生命   0 【自身架势  22 自身架势（旧）  82】 目标生命 122 【目标架势  39 目标架势（旧）  39】
# 读取结果：自身生命   0 【自身架势  21 自身架势（旧）  22】 目标生命 122 【目标架势  39 目标架势（旧）  39】
# 读取结果：自身生命   0 【自身架势  21 自身架势（旧）  22】 目标生命 122 【目标架势  38 目标架势（旧）  39】
# 读取结果：自身生命   0 【自身架势  21 自身架势（旧）  22】 目标生命 122 【目标架势  37 目标架势（旧）  38】
# 读取结果：自身生命   0 【自身架势  21 自身架势（旧）  22】 目标生命 122 【目标架势  36 目标架势（旧）  37】
# 读取结果：自身生命   0 【自身架势  21 自身架势（旧）  22】 目标生命 122 【目标架势  36 目标架势（旧）  36】
# 读取结果：自身生命   0 【自身架势  21 自身架势（旧）  22】 目标生命 122 【目标架势  35 目标架势（旧）  35】
# 读取结果：自身生命   0 【自身架势  21 自身架势（旧）  22】 目标生命 122 【目标架势  34 目标架势（旧）  34】
# 读取结果：自身生命   0 【自身架势  21 自身架势（旧）  22】 目标生命 122 【目标架势  33 目标架势（旧）  33】
# 读取结果：自身生命   0 【自身架势  21 自身架势（旧）  22】 目标生命 122 【目标架势  32 目标架势（旧）  33】
# 读取结果：自身生命   0 【自身架势  21 自身架势（旧）  22】 目标生命 122 【目标架势  31 目标架势（旧）  32】
# 读取结果：自身生命   0 【自身架势  21 自身架势（旧）  22】 目标生命 122 【目标架势  30 目标架势（旧）  31】
# 读取结果：自身生命   0 【自身架势  21 自身架势（旧）  22】 目标生命 122 【目标架势  29 目标架势（旧）  30】
# 读取结果：自身生命   0 【自身架势  21 自身架势（旧）  22】 目标生命 122 【目标架势  28 目标架势（旧）  29】
# 读取结果：自身生命   0 【自身架势  21 自身架势（旧）  22】 目标生命 122 【目标架势  28 目标架势（旧）  28】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）  82】 目标生命 122 【目标架势  27 目标架势（旧）  28】
# 读取结果：自身生命 127 【自身架势   1 自身架势（旧）   1】 目标生命 122 【目标架势  27 目标架势（旧）  27】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  26 目标架势（旧）  27】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  26 目标架势（旧）  27】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  26 目标架势（旧）  26】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  25 目标架势（旧）  25】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  24 目标架势（旧）  25】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  23 目标架势（旧）  24】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势  22 目标架势（旧）  23】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 120 【目标架势  24 目标架势（旧）  25】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 120 【目标架势  24 目标架势（旧）  25】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 120 【目标架势  24 目标架势（旧）  25】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 120 【目标架势  24 目标架势（旧）  25】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 120 【目标架势  24 目标架势（旧）  24】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 120 【目标架势  26 目标架势（旧）  26】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 120 【目标架势  26 目标架势（旧）  26】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 120 【目标架势  26 目标架势（旧）  26】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势  28 目标架势（旧）  29】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势  28 目标架势（旧）  29】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势  37 目标架势（旧）  38】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势  37 目标架势（旧）  38】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势  37 目标架势（旧）  38】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势  37 目标架势（旧）  38】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势  37 目标架势（旧）  38】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势  37 目标架势（旧）  38】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势  37 目标架势（旧）  38】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势  37 目标架势（旧）  38】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 117 【目标架势  36 目标架势（旧）  37】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 114 【目标架势  39 目标架势（旧）  39】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 114 【目标架势  39 目标架势（旧）  39】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 114 【目标架势  41 目标架势（旧）  41】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 114 【目标架势  41 目标架势（旧）  41】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 114 【目标架势  41 目标架势（旧）  41】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 111 【目标架势  43 目标架势（旧）  44】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 111 【目标架势  43 目标架势（旧）  44】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 111 【目标架势  43 目标架势（旧）  44】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 111 【目标架势  43 目标架势（旧）  44】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 111 【目标架势  43 目标架势（旧）  44】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 111 【目标架势  43 目标架势（旧）  44】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命 111 【目标架势  43 目标架势（旧）  44】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命 111 【目标架势  43 目标架势（旧）  44】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命 111 【目标架势  43 目标架势（旧）  44】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命 111 【目标架势  43 目标架势（旧）  44】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  81 【目标架势   1 目标架势（旧） 107】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  81 【目标架势   1 目标架势（旧）  54】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  81 【目标架势  53 目标架势（旧）  54】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  81 【目标架势  53 目标架势（旧）  54】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  81 【目标架势  53 目标架势（旧）  54】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  81 【目标架势  53 目标架势（旧）  54】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  81 【目标架势  53 目标架势（旧）  54】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  78 【目标架势  56 目标架势（旧）  56】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  78 【目标架势  56 目标架势（旧）  56】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  78 【目标架势  56 目标架势（旧）  56】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  76 【目标架势  58 目标架势（旧）  59】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  76 【目标架势  58 目标架势（旧）  59】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  76 【目标架势  58 目标架势（旧）  59】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  73 【目标架势  61 目标架势（旧）  61】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  73 【目标架势  61 目标架势（旧）  61】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  70 【目标架势  63 目标架势（旧）  64】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  70 【目标架势  63 目标架势（旧）  64】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  67 【目标架势  65 目标架势（旧）  66】
# 读取结果：自身生命 108 【自身架势   0 自身架势（旧）   0】 目标生命  67 【目标架势  65 目标架势（旧）  66】
# 读取结果：自身生命 108 【自身架势  11 自身架势（旧）  11】 目标生命  67 【目标架势  68 目标架势（旧）  69】
# 读取结果：自身生命 108 【自身架势  11 自身架势（旧）  11】 目标生命  67 【目标架势  68 目标架势（旧）  69】
# 读取结果：自身生命 108 【自身架势  18 自身架势（旧）  18】 目标生命  67 【目标架势  71 目标架势（旧）  72】
# 读取结果：自身生命 108 【自身架势  18 自身架势（旧）  18】 目标生命  67 【目标架势  71 目标架势（旧）  72】
# 读取结果：自身生命 108 【自身架势  25 自身架势（旧）  25】 目标生命  67 【目标架势  74 目标架势（旧）  75】
# 读取结果：自身生命 108 【自身架势  32 自身架势（旧）  32】 目标生命  67 【目标架势  77 目标架势（旧）  78】
# 读取结果：自身生命 108 【自身架势  32 自身架势（旧）  32】 目标生命  67 【目标架势  77 目标架势（旧）  78】
# 读取结果：自身生命 108 【自身架势  39 自身架势（旧）  39】 目标生命  67 【目标架势  80 目标架势（旧）  81】
# 读取结果：自身生命 108 【自身架势  45 自身架势（旧）  46】 目标生命  67 【目标架势  83 目标架势（旧）  84】
# 读取结果：自身生命 108 【自身架势  45 自身架势（旧）  46】 目标生命  67 【目标架势  83 目标架势（旧）  84】
# 读取结果：自身生命 108 【自身架势  45 自身架势（旧）  46】 目标生命  67 【目标架势  83 目标架势（旧）  84】
# 读取结果：自身生命 108 【自身架势  44 自身架势（旧）  45】 目标生命  67 【目标架势  83 目标架势（旧）  84】
# 读取结果：自身生命 108 【自身架势  58 自身架势（旧）  59】 目标生命  67 【目标架势  86 目标架势（旧）  87】
# 读取结果：自身生命 108 【自身架势  58 自身架势（旧）  59】 目标生命  67 【目标架势  86 目标架势（旧）  87】
# 读取结果：自身生命 108 【自身架势  58 自身架势（旧）  59】 目标生命  67 【目标架势  86 目标架势（旧）  87】
# 读取结果：自身生命 108 【自身架势  58 自身架势（旧）  59】 目标生命  67 【目标架势  86 目标架势（旧）  87】
# 读取结果：自身生命 108 【自身架势  58 自身架势（旧）  59】 目标生命  67 【目标架势  86 目标架势（旧）  87】
# 读取结果：自身生命 108 【自身架势  58 自身架势（旧）  59】 目标生命  67 【目标架势  86 目标架势（旧）  87】
# 读取结果：自身生命 108 【自身架势  57 自身架势（旧）  58】 目标生命  67 【目标架势  86 目标架势（旧）  87】
# 读取结果：自身生命 108 【自身架势  55 自身架势（旧）  56】 目标生命  67 【目标架势  86 目标架势（旧）  87】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  67 【目标架势  96 目标架势（旧）  96】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  67 【目标架势  96 目标架势（旧）  96】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  67 【目标架势  96 目标架势（旧）  96】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  67 【目标架势  96 目标架势（旧）  96】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  67 【目标架势  96 目标架势（旧）  96】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  67 【目标架势  96 目标架势（旧）  96】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  67 【目标架势  96 目标架势（旧）  96】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  67 【目标架势  95 目标架势（旧）  96】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  67 【目标架势  95 目标架势（旧）  96】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  65 【目标架势   1 目标架势（旧） 113】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  65 【目标架势   1 目标架势（旧）  98】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  65 【目标架势  97 目标架势（旧）  98】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  65 【目标架势 100 目标架势（旧） 100】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  65 【目标架势  99 目标架势（旧） 100】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  65 【目标架势 101 目标架势（旧） 101】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  65 【目标架势 101 目标架势（旧） 101】
# 读取结果：自身生命 108 【自身架势  53 自身架势（旧）  54】 目标生命  65 【目标架势 101 目标架势（旧） 101】
# 读取结果：自身生命 108 【自身架势  51 自身架势（旧）  52】 目标生命  65 【目标架势 101 目标架势（旧） 101】
# 读取结果：自身生命 108 【自身架势  49 自身架势（旧）  50】 目标生命  65 【目标架势 101 目标架势（旧） 101】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  65 【目标架势 104 目标架势（旧） 104】
# 读取结果：自身生命 108 【自身架势  54 自身架势（旧）  55】 目标生命  65 【目标架势 104 目标架势（旧） 104】
# 读取结果：自身生命 108 【自身架势  79 自身架势（旧）  78】 目标生命  65 【目标架势 107 目标架势（旧） 142】
# 读取结果：自身生命 108 【自身架势  61 自身架势（旧）  62】 目标生命  65 【目标架势 107 目标架势（旧） 132】
# 读取结果：自身生命 108 【自身架势  61 自身架势（旧）  62】 目标生命  65 【目标架势 107 目标架势（旧） 108】
# 读取结果：自身生命 108 【自身架势  61 自身架势（旧）  62】 目标生命  62 【目标架势 110 目标架势（旧） 111】
# 读取结果：自身生命 108 【自身架势  61 自身架势（旧）  62】 目标生命  62 【目标架势 110 目标架势（旧） 113】
# 读取结果：自身生命 108 【自身架势  61 自身架势（旧）  62】 目标生命  62 【目标架势 110 目标架势（旧） 111】
# 读取结果：自身生命 108 【自身架势  68 自身架势（旧）  68】 目标生命  62 【目标架势 113 目标架势（旧） 114】
# 读取结果：自身生命 108 【自身架势  75 自身架势（旧）  75】 目标生命  62 【目标架势 116 目标架势（旧） 117】
# 读取结果：自身生命 108 【自身架势  75 自身架势（旧）  75】 目标生命  62 【目标架势 116 目标架势（旧） 117】
# 读取结果：自身生命 108 【自身架势  80 自身架势（旧）  80】 目标生命  62 【目标架势 119 目标架势（旧） 120】
# 读取结果：自身生命 108 【自身架势  80 自身架势（旧）  80】 目标生命  62 【目标架势 119 目标架势（旧） 120】
# 读取结果：自身生命 108 【自身架势  80 自身架势（旧）  81】 目标生命  62 【目标架势 122 目标架势（旧） 123】
# 读取结果：自身生命  86 【自身架势   0 自身架势（旧）  82】 目标生命  62 【目标架势 122 目标架势（旧） 123】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 122 目标架势（旧） 123】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 122 目标架势（旧） 123】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 122 目标架势（旧） 123】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 122 目标架势（旧） 123】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 122 目标架势（旧） 123】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 122 目标架势（旧） 123】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 121 目标架势（旧） 122】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 121 目标架势（旧） 122】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 121 目标架势（旧） 122】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 121 目标架势（旧） 122】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 121 目标架势（旧） 122】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 121 目标架势（旧） 122】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 121 目标架势（旧） 122】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 120 目标架势（旧） 121】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 120 目标架势（旧） 121】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 120 目标架势（旧） 121】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 120 目标架势（旧） 121】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 120 目标架势（旧） 121】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 120 目标架势（旧） 121】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 120 目标架势（旧） 121】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 120 目标架势（旧） 121】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 120 目标架势（旧） 121】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 120 目标架势（旧） 121】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 120 目标架势（旧） 120】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 120 目标架势（旧） 120】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 122 目标架势（旧） 123】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 122 目标架势（旧） 123】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 123 目标架势（旧） 124】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 123 目标架势（旧） 124】
# 读取结果：自身生命 127 【自身架势   0 自身架势（旧）   0】 目标生命  62 【目标架势 123 目标架势（旧） 124】
# 读取结果：自身生命 127 【自身架势  11 自身架势（旧）  11】 目标生命  62 【目标架势 126 目标架势（旧） 127】
# 读取结果：自身生命 127 【自身架势  11 自身架势（旧）  11】 目标生命  62 【目标架势 126 目标架势（旧） 127】
# 读取结果：自身生命 127 【自身架势  11 自身架势（旧）  11】 目标生命  62 【目标架势 126 目标架势（旧） 127】
# 读取结果：自身生命 127 【自身架势  11 自身架势（旧）  11】 目标生命  62 【目标架势 129 目标架势（旧） 130】
# 读取结果：自身生命 127 【自身架势  11 自身架势（旧）  11】 目标生命  62 【目标架势 129 目标架势（旧） 130】
# 读取结果：自身生命 127 【自身架势  11 自身架势（旧）  11】 目标生命  62 【目标架势 129 目标架势（旧） 130】
# 读取结果：自身生命 127 【自身架势  11 自身架势（旧）  11】 目标生命  59 【目标架势 131 目标架势（旧） 132】
# 读取结果：自身生命 127 【自身架势  11 自身架势（旧）  11】 目标生命  59 【目标架势 131 目标架势（旧） 132】
# 读取结果：自身生命 127 【自身架势  11 自身架势（旧）  11】 目标生命  59 【目标架势 131 目标架势（旧） 132】
# 读取结果：自身生命 127 【自身架势   8 自身架势（旧）   9】 目标生命  59 【目标架势 131 目标架势（旧） 132】
# 读取结果：自身生命 127 【自身架势   6 自身架势（旧）   6】 目标生命  59 【目标架势 131 目标架势（旧） 132】
# 读取结果：自身生命 127 【自身架势   6 自身架势（旧）   6】 目标生命  59 【目标架势 131 目标架势（旧） 132】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  59 【目标架势 131 目标架势（旧） 132】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  59 【目标架势 127 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  59 【目标架势 127 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  59 【目标架势 131 目标架势（旧） 132】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  30 【目标架势 141 目标架势（旧） 142】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  30 【目标架势 141 目标架势（旧） 142】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  30 【目标架势 141 目标架势（旧） 142】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  30 【目标架势 141 目标架势（旧） 142】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  30 【目标架势 141 目标架势（旧） 142】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  30 【目标架势 141 目标架势（旧） 142】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  30 【目标架势 141 目标架势（旧） 142】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  27 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  27 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  27 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  24 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  24 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  24 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  24 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  24 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  24 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  24 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  24 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  24 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  24 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  24 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  24 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 108 【自身架势   6 自身架势（旧）   6】 目标生命  24 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   1 自身架势（旧）   1】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   1】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   1 自身架势（旧）   1】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 160 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧） 143】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命  71 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命  97 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命 122 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命 212 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   0 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命   1 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命 168 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命 109 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  12 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  12 【目标架势   0 目标架势（旧）   0】
# 读取结果：自身生命   0 【自身架势   0 自身架势（旧）   0】 目标生命  12 【目标架势   0 目标架势（旧）   0】
#
# Done!
