# %% [markdown]
# # 01

# %%
train.run()
# Out:
# Ready!
#
# Starting!
# step:  7479. Loop took 0.216 seconds. action 2, Self HP:   0, Self Posture:   0, Target HP:   0, Target Posture:   0. , total_reward:  -652.100, memory:7475.
# Done!

# %%
train.run()
# Out:
# Load Genichiro_Ashina_memory.json
# Ready!
#
# Starting!
# step:  8390. Loop took 0.254 seconds. action 3, Self HP:   0, Self Posture:   0, Target HP:   0, Target Posture:   0. , total_reward:  -558.900, memory:15863.
# Done!

# %% [markdown]
# 这第二把打的，我真的是无语了。在空中踩到Boss会造成伤害，然后Agent利用这个还有作弊（无限生命），硬生生一脚一脚把boss踩死。
# 我不打算让这个模型继续训练下去了。

# %% [markdown]
# # 02

# %%
train.run()
# Out:
# No memory to load.
# Ready!
#
# Starting!
# step:  4178. Loop took 0.339 seconds. action 4, Self HP:   0, Self Posture:   0, Target HP:   0, Target Posture:   0. , total_reward:   -61.500, memory:4176.
# Done!

# %%
train.run()
# Out:
# Load Genichiro_Ashina_memory.json
# Ready!
#
# Starting!
# step:  3492. Loop took 0.306 seconds. action 0, Self HP:   0, Self Posture:   0, Target HP:   0, Target Posture:   0. , total_reward:   -81.900, memory:7666.
# Done!

# %%
train.run()
# Out:
# Load Genichiro_Ashina_memory.json
# Ready!
#
# Starting!
# step:  3656. Loop took 0.363 seconds. action 4, Self HP:   0, Self Posture:   0, Target HP:   0, Target Posture:   0. , total_reward:   -33.300, memory:11320.
# Done!
